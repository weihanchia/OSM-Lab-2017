# %%
run olg3pernol.py

# %% [markdown]
# # Problem 1

# %%
# First let us initialize some arguments
args = (0.96, 3,1, 0.35, 0.05)
n = np.array([1,1,0.2])
model = olg3pernol(n,args)
print(model)
# Out:
# Individual Parameters:
# Discount Rate:	0.4420024338794074
# Relative Risk Aversion:	3
# Firm Parameters:
# Technology:	1
# Capital Share:	0.35
# Depreciation:	0.6415140775914581

# %%
#Now we want to compute steady state.
b_init = np.array([0.1,0.5])
model.ss(b_init)
# Out:
# Steady State
# Second/Third Period Saving:	[ 0.01931274  0.05841159]
# Consumption:	[ 0.18241256  0.20961491  0.24087382]
# Wages:	0.201725293596
# Rental Rate:	2.43303025356

# %% [markdown]
# # Problem 2

# %%
#What happens when we change beta?
bnew = 0.55 ** (1/20)
argnew = (bnew, 3, 1, 0.35, 0.05)
model2 = olg3pernol(n,argnew)
print(model2)
model2.ss(b_init)
# Out:
# Individual Parameters:
# Discount Rate:	0.5499999999999997
# Relative Risk Aversion:	3
# Firm Parameters:
# Technology:	1
# Capital Share:	0.35
# Depreciation:	0.6415140775914581
# Steady State
# Second/Third Period Saving:	[ 0.02817696  0.07686557]
# Consumption:	[ 0.19597535  0.22861559  0.26669216]
# Wages:	0.22415231191
# Rental Rate:	1.88635999915

# %% [markdown]
# # Problem 3

# %%
perturbation = np.array([0.8,1.1])
pb = perturbation * model.bss
ss = model.perturb(pb, chi = 0.01, T=50)
print(ss)
# Out:
# Iternation number: 0 Error: 0.00619273886398
# Iternation number: 1 Error: 0.00242748803176
# Iternation number: 2 Error: 0.00103943564231
# Iternation number: 3 Error: 0.000450436020916
# Iternation number: 4 Error: 0.00019850357891
# Iternation number: 5 Error: 8.80955981837e-05
# Iternation number: 6 Error: 3.92520229445e-05
# Iternation number: 7 Error: 1.75213315958e-05
# Iternation number: 8 Error: 7.82778965546e-06
# Iternation number: 9 Error: 3.49808058065e-06
# Iternation number: 10 Error: 1.56311807075e-06
# Iternation number: 11 Error: 6.98270500371e-07
# Iternation number: 12 Error: 3.11779229493e-07
# Iternation number: 13 Error: 1.39121605252e-07
# Iternation number: 14 Error: 6.20301041576e-08
# Iternation number: 15 Error: 2.7631718893e-08
# Iternation number: 16 Error: 1.22954718155e-08
# Iternation number: 17 Error: 5.46441841808e-09
# Iternation number: 18 Error: 2.4250818659e-09
# Iternation number: 19 Error: 1.07449605395e-09
# Iternation number: 20 Error: 4.75201851681e-10
# Iternation number: 21 Error: 2.09714172616e-10
# Iternation number: 22 Error: 9.23234485635e-11
# Iternation number: 23 Error: 4.05282822786e-11
# Iternation number: 24 Error: 1.77318034649e-11
# Iternation number: 25 Error: 7.72718858655e-12
# Iternation number: 26 Error: 3.35106091607e-12
# Iternation number: 27 Error: 1.44405744849e-12
# Iternation number: 28 Error: 6.16641553394e-13
# [[ 0.01545019  0.06425275]
#  [ 0.02042276  0.05475618]
#  [ 0.01857245  0.05912066]
#  [ 0.01943549  0.05767568]
#  [ 0.01916182  0.05843445]
#  [ 0.01931222  0.05824163]
#  [ 0.01927694  0.05838353]
#  [ 0.01930557  0.05836587]
#  [ 0.01930286  0.05839595]
#  [ 0.0193091   0.0583977 ]
#  [ 0.01930968  0.05840516]
#  [ 0.01931127  0.05840704]
#  [ 0.01931173  0.05840918]
#  [ 0.01931219  0.05841004]
#  [ 0.01931239  0.05841071]
#  [ 0.01931254  0.05841105]
#  [ 0.01931261  0.05841128]
#  [ 0.01931267  0.0584114 ]
#  [ 0.01931269  0.05841148]
#  [ 0.01931271  0.05841152]
#  [ 0.01931272  0.05841155]
#  [ 0.01931273  0.05841157]
#  [ 0.01931273  0.05841158]
#  [ 0.01931273  0.05841158]
#  [ 0.01931273  0.05841159]
#  [ 0.01931273  0.05841159]
#  [ 0.01931273  0.05841159]
#  [ 0.01931273  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]
#  [ 0.01931274  0.05841159]]

# %% [markdown]
# # Problem 4

# %%
# %matplotlib notebook

plt.plot(ss.sum(axis=1))
plt.title('Transition Path of Capital', fontsize=20)
plt.xlabel('Time')
plt.ylabel('Capital')
# Out:
# <img src="data:image/png;base64,..." width="640">
