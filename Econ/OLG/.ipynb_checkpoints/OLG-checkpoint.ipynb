# %%
run olg3pernol.py

# %% [markdown]
# # Problem 1

# %%
# First let us initialize some arguments
args = (0.96, 3,1, 0.35, 0.05)
n = np.array([1,1,0.2])
model = olg3pernol(n,args)
print(model)
# Out:
# Individual Parameters:
# Discount Rate:	0.4420024338794074
# Relative Risk Aversion:	3
# Firm Parameters:
# Technology:	1
# Capital Share:	0.35
# Depreciation:	0.6415140775914581

# %%
#Now we want to compute steady state.
b_init = np.array([0.1,0.5])
model.ss(b_init)
# Out:
# Steady State
# Second/Third Period Saving:	[ 0.01931274  0.05841159]
# Consumption:	[ 0.18241256  0.20961491  0.24087382]
# Wages:	0.201725293596
# Rental Rate:	2.43303025356

# %% [markdown]
# # Problem 2

# %%
#What happens when we change beta?
bnew = 0.55 ** (1/20)
argnew = (bnew, 3, 1, 0.35, 0.05)
model2 = olg3pernol(n,argnew)
print(model2)
model2.ss(b_init)
# Out:
# Individual Parameters:
# Discount Rate:	0.5499999999999997
# Relative Risk Aversion:	3
# Firm Parameters:
# Technology:	1
# Capital Share:	0.35
# Depreciation:	0.6415140775914581
# Steady State
# Second/Third Period Saving:	[ 0.02817696  0.07686557]
# Consumption:	[ 0.19597535  0.22861559  0.26669216]
# Wages:	0.22415231191
# Rental Rate:	1.88635999915

# %% [markdown]
# # Problem 3

# %%
perturbation = np.array([0.8,1.1])
pb = perturbation * model.bss
ss = model.perturb(pb, chi = 0.01, T=50)
# Out:
# Iternation number: 0 Error: 0.00623394817926
# Iternation number: 1 Error: 0.00232131507724
# Iternation number: 2 Error: 0.000964928035753
# Iternation number: 3 Error: 0.000419891632225
# Iternation number: 4 Error: 0.000185235922647
# Iternation number: 5 Error: 8.21802213446e-05
# Iternation number: 6 Error: 3.65580754446e-05
# Iternation number: 7 Error: 1.62897716527e-05
# Iternation number: 8 Error: 7.26730488338e-06
# Iternation number: 9 Error: 3.2446826215e-06
# Iternation number: 10 Error: 1.44939504915e-06
# Iternation number: 11 Error: 6.47644440993e-07
# Iternation number: 12 Error: 2.89453800054e-07
# Iternation number: 13 Error: 1.29382677293e-07
# Iternation number: 14 Error: 5.7834195964e-08
# Iternation number: 15 Error: 2.58508782032e-08
# Iternation number: 16 Error: 1.15537880205e-08
# Iternation number: 17 Error: 5.16308444772e-09
# Iternation number: 18 Error: 2.30678609303e-09
# Iternation number: 19 Error: 1.03037897447e-09
# Iternation number: 20 Error: 4.60106513938e-10
# Iternation number: 21 Error: 2.05386459006e-10
# Iternation number: 22 Error: 9.16466359587e-11
# Iternation number: 23 Error: 4.08762257848e-11
# Iternation number: 24 Error: 1.82227516193e-11
# Iternation number: 25 Error: 8.11933237065e-12
# Iternation number: 26 Error: 3.61550351897e-12
# Iternation number: 27 Error: 1.6088788045e-12
# Iternation number: 28 Error: 7.15426608907e-13

# %% [markdown]
# # Problem 4

# %%
# %matplotlib notebook

plt.plot(ss.sum(axis=1))
plt.title('Transition Path of Capital', fontsize=20)
plt.xlabel('Time')
plt.ylabel('Capital')
# Out:
# <img src="data:image/png;base64,..." width="640">
